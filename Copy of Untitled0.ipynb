# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_excel("cleaned_newdata.xlsx")

# %%
df.head()
# Out:
#           order_id  order_date  ship_date       ship_mode    customer_name  \
# 0     AG-2011-2040       40544      40549  Standard Class  Toby Braunhardt
# 1    IN-2011-47883       40544      40551  Standard Class      Joseph Holt
# 2     HU-2011-1220       40544      40548    Second Class    Annie Thurman
# 3  IT-2011-3647632       40544      40548    Second Class     Eugene Moren
# 4     CA-2011-1510       40544      40551  Standard Class      Joseph Holt
#
#        segment            state    country          market   region  ...  \
# 0     Consumer      Constantine    Algeria          Africa   Africa  ...
# 1     Consumer  New South Wales  Australia            APAC  Oceania  ...
# 2     Consumer         Budapest    Hungary            EMEA     EMEA  ...
# 3  Home Office        Stockholm     Sweden              EU    North  ...
# 4     Consumer  New South Wales  Australia            APAC  Oceania  ...
#
# ...

# %%
df
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51298 entries, 0 to 51297
# Data columns (total 28 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   order_id        51277 non-null  object
#  1   order_date      51298 non-null  int64
#  2   ship_date       51298 non-null  int64
#  3   ship_mode       51298 non-null  object
#  4   customer_name   51298 non-null  object
#  5   segment         51298 non-null  object
#  6   state           51298 non-null  object
#  7   country         51298 non-null  object
#  8   market          51298 non-null  object
#  9   region          51298 non-null  object
#  10  product_id      51277 non-null  object
#  11  category        51298 non-null  object
#  12  sub_category    51298 non-null  object
#  13  product_name    51298 non-null  object
#  14  product_name.1  43525 non-null  object
#  15  product_name.2  701 non-null    object
#  16  product_name.3  161 non-null    object
# ...
